# %% [markdown]
# # **Theory Questions:**

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# ->>Function -
#   * function is defined using the def
#   keyword or lambda.
#   * functiona call a directly by its name.
#   * it exist independantly.

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Sagar"))
# Out:
# Hello, Sagar!

# %% [markdown]
# Method -
# * A method is a function that is associated with an object.
# * it is defined a inside class.
# * call a method on an object using dot notation.

# %%
class Greeter:
    def greet(self, name):
        return f"Hello, {name}!"

g = Greeter()
print(g.greet("Sagar"))
# Out:
# Hello, Sagar!

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#
# ->>
#   * Parameters are placeholders used in the function definition.
#   * Arguments are the actual values you pass when calling the function.
#
#   Python supports several types of parameters and arguments-
#   * positional arguments.
#   * keyword arguments.
#   * default parameters.
#   * variable length arguments.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#
# ->> * Standard Function Definition

# %%
def greet(name):
    return f"Hello, {name}!"

greet("Sagar")
# Out:
# 'Hello, Sagar!'

# %% [markdown]
# *  Function with Default Arguments

# %%
def greet(name="Guest"):
    return f"Hello, {name}!"

greet()  # default Guest
greet("Sagar")
# Out:
# 'Hello, Sagar!'

# %% [markdown]
# * Variable-Length Arguments

# %%
def add_all(*numbers):
    return sum(numbers)

add_all(1, 2, 3, 4)
# Out:
# 10

# %% [markdown]
# * Lambda function

# %%
square = lambda x: x ** 2
square(4)
# Out:
# 16

# %%
list(map(lambda x: x*2, [1, 2, 3]))
# Out:
# [2, 4, 6]

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
#
# ->>
# * send a result back to the caller.
# * end function execution immediately.

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
#
# ->>
#   Iterable-
#   * iterable is any object that can be looped over.
#   * It has a iter() method that returns an iterator.
#   * Examples: list, tuple, str, dict, set.
#
#   Iterator-
#   * iterator is the object that actually does the iteration.
#   * it has a two methods iter() or next()

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#
# ->> A generator is a special type of iterator that yields values one at a time.
#
# Memory efficient, clean syntax, lazy evaluatiion, infinite sequence.
#
# generators deined using yield function and generator expression.

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#
# ->>
#
# * memory efficient.
# * lazy evaluation.
# * infinite.
# * bon demand sequence.
# * performance boost iteration.
# * simpler code.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#
# ->>
#  * Defined with the keyword lambda.
#  * Takes any number of arguments.
#  * Has only one expression.
#  * Returns the result of that expression automatically.
#  * syntac - lambda arguments: expression
#
#  lambda function used with map(), reduce(), filter(), sorted()

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
#
# ->>
# * Apply a function to every item in an iterable.
# * returns an iterator.
# * common pairing with lambda.
# * syntax- map(function, iterable)

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# ->>
# Map() -
#
# * Transforms each item.
# * returns iterator.
# * use to apply function to all items.
# * no need to import.
# * syntax- map(func, iterable)
#
# reduce()
# * Reduces all items to one value.
# * returns single value.
# * need to import from function.
# * syntax- reduce(func, iterable)
#
# filter()
# * Filters items based on condition.
# * returns iterator.
# * no need to import.
# * syntax- filter(func, iterable)

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# ->>

# %%
from functools import reduce

numbers = [47, 11, 42, 13]

result = reduce(lambda x, y: x + y, numbers)

# %%
result
# Out:
# 113

# %% [markdown]
# ![c67074c2-24a0-4449-a9a3-e0e9314c408b.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Practical Questions:**

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
def sum_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total

nums = [47, 11, 42, 13, 8, 4]
result = sum_even_numbers(nums)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 54

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
def reverse_string(s):
    return s[::-1]

text = "Hello, world!"
reversed_text = reverse_string(text)
print("Reversed:", reversed_text)
# Out:
# Reversed: !dlrow ,olleH

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number.

# %%
def square_numbers(numbers):
    return [num ** 2 for num in numbers]

nums = [1, 2, 3, 4, 5]
squared = square_numbers(nums)
print("Squared List:", squared)
# Out:
# Squared List: [1, 4, 9, 16, 25]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 2 or n > 200:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# %%
for num in range(1, 201):
    if is_prime(num):
        print(f"{num} is a prime number.")
# Out:
# 2 is a prime number.
# 3 is a prime number.
# 5 is a prime number.
# 7 is a prime number.
# 11 is a prime number.
# 13 is a prime number.
# 17 is a prime number.
# 19 is a prime number.
# 23 is a prime number.
# 29 is a prime number.
# 31 is a prime number.
# 37 is a prime number.
# 41 is a prime number.
# 43 is a prime number.
# 47 is a prime number.
# 53 is a prime number.
# 59 is a prime number.
# 61 is a prime number.
# 67 is a prime number.
# 71 is a prime number.
# 73 is a prime number.
# 79 is a prime number.
# 83 is a prime number.
# 89 is a prime number.
# 97 is a prime number.
# 101 is a prime number.
# 103 is a prime number.
# 107 is a prime number.
# 109 is a prime number.
# 113 is a prime number.
# 127 is a prime number.
# 131 is a prime number.
# 137 is a prime number.
# 139 is a prime number.
# 149 is a prime number.
# 151 is a prime number.
# 157 is a prime number.
# 163 is a prime number.
# 167 is a prime number.
# 173 is a prime number.
# 179 is a prime number.
# ...

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, num_terms):
        self.num_terms = num_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.num_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a

# %%
fib = FibonacciIterator(10)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exponent):
    for exp in range(max_exponent + 1):
        yield 2 ** exp

# %%
for power in powers_of_two(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_line_by_line(file_path):
    try:
        with open(file_path, 'r') as file:
            for line in file:
                yield line.rstrip('\n')  # Strip newline characters
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
    except IOError as e:
        print(f"IO error occurred: {e}")

# %%
for line in read_file_line_by_line('example.txt'):
    print(line)
# Out:
# Error: The file 'example.txt' was not found.

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
data = [(1, 3), (4, 1), (2, 2), (5, 0)]

sorted_data = sorted(data, key=lambda x: x[1])

print(sorted_data)
# Out:
# [(5, 0), (4, 1), (2, 2), (1, 3)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius = [0, 10, 20, 30, 40]

fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))

print("Celsius:", celsius)
print("Fahrenheit:", fahrenheit)
# Out:
# Celsius: [0, 10, 20, 30, 40]
# Fahrenheit: [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def remove_vowels(input_str):
    vowels = 'aeiouAEIOU'
    return ''.join(filter(lambda char: char not in vowels, input_str))

text = "Hello, World!"
result = remove_vowels(text)
print("Original string:", text)
print("Without vowels:", result)
# Out:
# Original string: Hello, World!
# Without vowels: Hll, Wrld!

# %% [markdown]
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(
    lambda order: (
        order[0],
        order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10
    ),
    orders
))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
